# %%
# %cd /content/drive/MyDrive/github_projects/dbt-project/mnt/python
# Out:
# /content/drive/MyDrive/github_projects/dbt-project/mnt/python

# %%
# !pytest tests/test_soma.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0
# rootdir: /content/drive/MyDrive/github_projects/dbt-project/mnt/python
# plugins: typeguard-4.4.4, anyio-4.10.0, langsmith-0.4.14
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting tests/test_soma.py ______________________
# ImportError while importing test module '/content/drive/MyDrive/github_projects/dbt-project/mnt/python/tests/test_soma.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.11/importlib/__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tests/test_soma.py:2: in <module>
#     from scripts.soma import soma
# ...

# %%
# !pytest tests/test_soma.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0
# rootdir: /content/drive/MyDrive/github_projects/dbt-project/mnt/python
# plugins: typeguard-4.4.4, anyio-4.10.0, langsmith-0.4.14
# collected 1 item
#
# tests/test_soma.py .                                                     [100%]
#
# ============================== 1 passed in 1.04s ===============================

# %%
# !pytest tests/test_extract_api.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0
# rootdir: /content/drive/MyDrive/github_projects/dbt-project/mnt/python
# plugins: typeguard-4.4.4, anyio-4.10.0, langsmith-0.4.14
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# __________________ ERROR collecting tests/test_extract_api.py __________________
# ImportError while importing test module '/content/drive/MyDrive/github_projects/dbt-project/mnt/python/tests/test_extract_api.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.11/importlib/__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tests/test_extract_api.py:2: in <module>
#     from extract_api import Extract
# ...

# %%
# !pytest tests/test_extract_api.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0
# rootdir: /content/drive/MyDrive/github_projects/dbt-project/mnt/python
# plugins: typeguard-4.4.4, anyio-4.10.0, langsmith-0.4.14
# collected 1 item
#
# tests/test_extract_api.py .                                              [100%]
#
# ============================== 1 passed in 0.10s ===============================

# %%
from src.extract_api import Extract

url = "https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal"
response = Extract(url).api_data()
response.status_code
# Out:
# 200
